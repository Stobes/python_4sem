# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#"Download datasettet fra dette link.
#https://www.kaggle.com/sanjeetsinghnaik/top-1000-highest-grossing-movies 

#1. Find the top 10 highest grossing Disney movies measured by world sales

#2. Create a pie chart that shows the distribution of Licenses (PG, R, M and so on)

#3. Get the percentage of PG rated movies between 2001 and 2015

#4. Calculate the average of world sales for each genre and visualize the data with a bar chart. (Hint: use groupBy)
#"

# %%
filename = 'Highest Holywood Grossing Movies.csv'
movies_df = np.genfromtxt(filename, delimiter=',', skip_header=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-65682812b19a> in <module>
#       1 filename = 'Highest Holywood Grossing Movies.csv'
# ----> 2 movies_df = np.genfromtxt(filename, delimiter=',', skip_header=1)
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2101             # Raise an exception ?
#    2102             if invalid_raise:
# -> 2103                 raise ValueError(errmsg)
#    2104             # Issue a warning ?
#    2105             else:
#
# ValueError: Some errors were detected !
#     Line #3 (got 17 columns instead of 19)
#     Line #4 (got 15 columns instead of 19)
#     Line #5 (got 15 columns instead of 19)
#     Line #6 (got 13 columns instead of 19)
#     Line #7 (got 17 columns instead of 19)
#     Line #8 (got 14 columns instead of 19)
#     Line #9 (got 18 columns instead of 19)
#     Line #10 (got 14 columns instead of 19)
#     Line #11 (got 16 columns instead of 19)
#     Line #12 (got 16 columns instead of 19)
#     Line #13 (got 17 columns instead of 19)
#     Line #14 (got 16 columns instead of 19)
#     Line #15 (got 16 columns instead of 19)
#     Line #16 (got 16 columns instead of 19)
#     Line #17 (got 17 columns instead of 19)
#     Line #18 (got 15 columns instead of 19)
#     Line #19 (got 21 columns instead of 19)
#     Line #20 (got 16 columns instead of 19)
#     Line #21 (got 18 columns instead of 19)
#     Line #22 (got 15 columns instead of 19)
#     Line #23 (got 17 columns instead of 19)
#     Line #24 (got 20 columns instead of 19)
#     Line #25 (got 14 columns instead of 19)
#     Line #26 (got 17 columns instead of 19)
#     Line #27 (got 14 columns instead of 19)
#     Line #28 (got 16 columns instead of 19)
#     Line #29 (got 15 columns instead of 19)
#     Line #30 (got 17 columns instead of 19)
#     Line #31 (got 15 columns instead of 19)
#     Line #32 (got 17 columns instead of 19)
#     Line #33 (got 20 columns instead of 19)
#     Line #34 (got 15 columns instead of 19)
#     Line #35 (got 14 columns instead of 19)
#     Line #36 (got 15 columns instead of 19)
#     Line #37 (got 17 columns instead of 19)
#     Line #38 (got 16 columns instead of 19)
#     Line #39 (got 15 columns instead of 19)
#     Line #40 (got 15 columns instead of 19)
#     Line #41 (got 20 columns instead of 19)
#     Line #42 (got 15 columns instead of 19)
#     Line #43 (got 16 columns instead of 19)
#     Line #44 (got 15 columns instead of 19)
#     Line #45 (got 16 columns instead of 19)
#     Line #46 (got 17 columns instead of 19)
#     Line #47 (got 15 columns instead of 19)
#     Line #48 (got 14 columns instead of 19)
#     Line #49 (got 13 columns instead of 19)
#     Line #50 (got 16 columns instead of 19)
#     Line #51 (got 21 columns instead of 19)
#     Line #52 (got 16 columns instead of 19)
#     Line #53 (got 16 columns instead of 19)
#     Line #54 (got 24 columns instead of 19)
#     Line #55 (got 17 columns instead of 19)
#     Line #56 (got 13 columns instead of 19)
#     Line #57 (got 15 columns instead of 19)
#     Line #58 (got 17 columns instead of 19)
#     Line #59 (got 18 columns instead of 19)
#     Line #60 (got 17 columns instead of 19)
#     Line #61 (got 16 columns instead of 19)
#     Line #62 (got 16 columns instead of 19)
#     Line #63 (got 22 columns instead of 19)
#     Line #64 (got 15 columns instead of 19)
#     Line #65 (got 16 columns instead of 19)
#     Line #66 (got 15 columns instead of 19)
#     Line #67 (got 16 columns instead of 19)
#     Line #68 (got 15 columns instead of 19)
#     Line #69 (got 16 columns instead of 19)
#     Line #70 (got 16 columns instead of 19)
#     Line #71 (got 15 columns instead of 19)
#     Line #72 (got 15 columns instead of 19)
#     Line #73 (got 16 columns instead of 19)
#     Line #75 (got 18 columns instead of 19)
#     Line #76 (got 17 columns instead of 19)
#     Line #77 (got 15 columns instead of 19)
#     Line #78 (got 16 columns instead of 19)
#     Line #79 (got 15 columns instead of 19)
#     Line #80 (got 15 columns instead of 19)
#     Line #82 (got 15 columns instead of 19)
#     Line #83 (got 17 columns instead of 19)
#     Line #84 (got 18 columns instead of 19)
#     Line #85 (got 17 columns instead of 19)
#     Line #86 (got 15 columns instead of 19)
#     Line #87 (got 17 columns instead of 19)
#     Line #88 (got 16 columns instead of 19)
#     Line #89 (got 15 columns instead of 19)
#     Line #90 (got 17 columns instead of 19)
#     Line #91 (got 20 columns instead of 19)
#     Line #93 (got 17 columns instead of 19)
#     Line #94 (got 15 columns instead of 19)
#     Line #95 (got 17 columns instead of 19)
#     Line #96 (got 17 columns instead of 19)
#     Line #97 (got 16 columns instead of 19)
#     Line #98 (got 17 columns instead of 19)
#     Line #99 (got 16 columns instead of 19)
#     Line #100 (got 15 columns instead of 19)
#     Line #101 (got 15 columns instead of 19)
#     Line #102 (got 21 columns instead of 19)
#     Line #103 (got 16 columns instead of 19)
#     Line #104 (got 13 columns instead of 19)
#     Line #105 (got 15 columns instead of 19)
#     Line #106 (got 15 columns instead of 19)
#     Line #107 (got 17 columns instead of 19)
#     Line #108 (got 13 columns instead of 19)
#     Line #109 (got 13 columns instead of 19)
#     Line #110 (got 15 columns instead of 19)
#     Line #111 (got 17 columns instead of 19)
#     Line #112 (got 16 columns instead of 19)
#     Line #113 (got 16 columns instead of 19)
#     Line #114 (got 18 columns instead of 19)
#     Line #115 (got 21 columns instead of 19)
#     Line #116 (got 15 columns instead of 19)
#     Line #117 (got 16 columns instead of 19)
#     Line #118 (got 17 columns instead of 19)
#     Line #119 (got 16 columns instead of 19)
#     Line #120 (got 15 columns instead of 19)
#     Line #121 (got 18 columns instead of 19)
#     Line #122 (got 16 columns instead of 19)
#     Line #123 (got 20 columns instead of 19)
#     Line #124 (got 14 columns instead of 19)
#     Line #125 (got 16 columns instead of 19)
#     Line #126 (got 15 columns instead of 19)
#     Line #127 (got 12 columns instead of 19)
#     Line #128 (got 18 columns instead of 19)
#     Line #129 (got 18 columns instead of 19)
#     Line #130 (got 14 columns instead of 19)
#     Line #131 (got 14 columns instead of 19)
#     Line #132 (got 15 columns instead of 19)
#     Line #133 (got 17 columns instead of 19)
#     Line #134 (got 18 columns instead of 19)
#     Line #135 (got 14 columns instead of 19)
#     Line #137 (got 15 columns instead of 19)
#     Line #138 (got 17 columns instead of 19)
#     Line #139 (got 16 columns instead of 19)
#     Line #140 (got 13 columns instead of 19)
#     Line #141 (got 16 columns instead of 19)
#     Line #142 (got 14 columns instead of 19)
#     Line #143 (got 16 columns instead of 19)
#     Line #144 (got 15 columns instead of 19)
#     Line #145 (got 17 columns instead of 19)
#     Line #146 (got 15 columns instead of 19)
#     Line #147 (got 18 columns instead of 19)
#     Line #148 (got 14 columns instead of 19)
#     Line #149 (got 16 columns instead of 19)
#     Line #150 (got 14 columns instead of 19)
#     Line #151 (got 14 columns instead of 19)
#     Line #152 (got 15 columns instead of 19)
#     Line #153 (got 14 columns instead of 19)
#     Line #154 (got 12 columns instead of 19)
#     Line #155 (got 16 columns instead of 19)
#     Line #156 (got 15 columns instead of 19)
#     Line #157 (got 17 columns instead of 19)
#     Line #158 (got 15 columns instead of 19)
#     Line #159 (got 15 columns instead of 19)
#     Line #160 (got 16 columns instead of 19)
#     Line #161 (got 14 columns instead of 19)
#     Line #162 (got 14 columns instead of 19)
#     Line #164 (got 16 columns instead of 19)
#     Line #165 (got 15 columns instead of 19)
#     Line #166 (got 16 columns instead of 19)
#     Line #167 (got 16 columns instead of 19)
#     Line #168 (got 18 columns instead of 19)
#     Line #169 (got 16 columns instead of 19)
#     Line #170 (got 14 columns instead of 19)
#     Line #171 (got 21 columns instead of 19)
#     Line #172 (got 15 columns instead of 19)
#     Line #173 (got 16 columns instead of 19)
#     Line #174 (got 16 columns instead of 19)
#     Line #175 (got 16 columns instead of 19)
#     Line #176 (got 17 columns instead of 19)
#     Line #177 (got 18 columns instead of 19)
#     Line #178 (got 16 columns instead of 19)
#     Line #179 (got 18 columns instead of 19)
#     Line #181 (got 14 columns instead of 19)
#     Line #182 (got 15 columns instead of 19)
#     Line #183 (got 15 columns instead of 19)
#     Line #184 (got 16 columns instead of 19)
#     Line #185 (got 22 columns instead of 19)
#     Line #186 (got 14 columns instead of 19)
#     Line #187 (got 14 columns instead of 19)
#     Line #188 (got 15 columns instead of 19)
#     Line #190 (got 15 columns instead of 19)
#     Line #191 (got 15 columns instead of 19)
#     Line #192 (got 17 columns instead of 19)
#     Line #193 (got 15 columns instead of 19)
#     Line #194 (got 16 columns instead of 19)
#     Line #195 (got 17 columns instead of 19)
#     Line #196 (got 13 columns instead of 19)
#     Line #197 (got 20 columns instead of 19)
#     Line #198 (got 14 columns instead of 19)
#     Line #199 (got 15 columns instead of 19)
#     Line #200 (got 15 columns instead of 19)
#     Line #201 (got 14 columns instead of 19)
#     Line #202 (got 16 columns instead of 19)
#     Line #203 (got 15 columns instead of 19)
#     Line #204 (got 17 columns instead of 19)
#     Line #205 (got 16 columns instead of 19)
#     Line #206 (got 15 columns instead of 19)
#     Line #207 (got 15 columns instead of 19)
#     Line #208 (got 16 columns instead of 19)
#     Line #209 (got 15 columns instead of 19)
#     Line #210 (got 14 columns instead of 19)
#     Line #211 (got 15 columns instead of 19)
#     Line #212 (got 16 columns instead of 19)
#     Line #213 (got 16 columns instead of 19)
#     Line #214 (got 18 columns instead of 19)
#     Line #215 (got 21 columns instead of 19)
#     Line #216 (got 21 columns instead of 19)
#     Line #217 (got 16 columns instead of 19)
#     Line #218 (got 15 columns instead of 19)
#     Line #219 (got 15 columns instead of 19)
#     Line #220 (got 16 columns instead of 19)
#     Line #221 (got 18 columns instead of 19)
#     Line #222 (got 20 columns instead of 19)
#     Line #223 (got 17 columns instead of 19)
#     Line #224 (got 16 columns instead of 19)
#     Line #225 (got 21 columns instead of 19)
#     Line #226 (got 14 columns instead of 19)
#     Line #227 (got 16 columns instead of 19)
#     Line #228 (got 16 columns instead of 19)
#     Line #229 (got 15 columns instead of 19)
#     Line #230 (got 15 columns instead of 19)
#     Line #231 (got 16 columns instead of 19)
#     Line #232 (got 17 columns instead of 19)
#     Line #234 (got 15 columns instead of 19)
#     Line #235 (got 18 columns instead of 19)
#     Line #236 (got 18 columns instead of 19)
#     Line #237 (got 15 columns instead of 19)
#     Line #238 (got 14 columns instead of 19)
#     Line #239 (got 21 columns instead of 19)
#     Line #240 (got 14 columns instead of 19)
#     Line #241 (got 17 columns instead of 19)
#     Line #242 (got 14 columns instead of 19)
#     Line #244 (got 15 columns instead of 19)
#     Line #245 (got 17 columns instead of 19)
#     Line #246 (got 14 columns instead of 19)
#     Line #247 (got 17 columns instead of 19)
#     Line #248 (got 16 columns instead of 19)
#     Line #249 (got 17 columns instead of 19)
#     Line #250 (got 13 columns instead of 19)
#     Line #251 (got 16 columns instead of 19)
#     Line #252 (got 13 columns instead of 19)
#     Line #253 (got 15 columns instead of 19)
#     Line #254 (got 15 columns instead of 19)
#     Line #255 (got 15 columns instead of 19)
#     Line #256 (got 16 columns instead of 19)
#     Line #257 (got 12 columns instead of 19)
#     Line #258 (got 16 columns instead of 19)
#     Line #259 (got 15 columns instead of 19)
#     Line #260 (got 16 columns instead of 19)
#     Line #261 (got 18 columns instead of 19)
#     Line #262 (got 17 columns instead of 19)
#     Line #263 (got 18 columns instead of 19)
#     Line #264 (got 16 columns instead of 19)
#     Line #265 (got 16 columns instead of 19)
#     Line #266 (got 13 columns instead of 19)
#     Line #267 (got 15 columns instead of 19)
#     Line #268 (got 14 columns instead of 19)
#     Line #269 (got 18 columns instead of 19)
#     Line #270 (got 16 columns instead of 19)
#     Line #271 (got 16 columns instead of 19)
#     Line #272 (got 18 columns instead of 19)
#     Line #273 (got 15 columns instead of 19)
#     Line #274 (got 16 columns instead of 19)
#     Line #275 (got 17 columns instead of 19)
#     Line #276 (got 17 columns instead of 19)
#     Line #277 (got 14 columns instead of 19)
#     Line #278 (got 18 columns instead of 19)
#     Line #279 (got 15 columns instead of 19)
#     Line #281 (got 14 columns instead of 19)
#     Line #282 (got 16 columns instead of 19)
#     Line #283 (got 16 columns instead of 19)
#     Line #284 (got 14 columns instead of 19)
#     Line #285 (got 14 columns instead of 19)
#     Line #286 (got 13 columns instead of 19)
#     Line #287 (got 15 columns instead of 19)
#     Line #288 (got 15 columns instead of 19)
#     Line #289 (got 13 columns instead of 19)
#     Line #290 (got 17 columns instead of 19)
#     Line #291 (got 14 columns instead of 19)
#     Line #292 (got 14 columns instead of 19)
#     Line #293 (got 14 columns instead of 19)
#     Line #295 (got 14 columns instead of 19)
#     Line #296 (got 13 columns instead of 19)
#     Line #297 (got 17 columns instead of 19)
#     Line #298 (got 16 columns instead of 19)
#     Line #299 (got 16 columns instead of 19)
#     Line #300 (got 16 columns instead of 19)
#     Line #301 (got 13 columns instead of 19)
#     Line #302 (got 18 columns instead of 19)
#     Line #303 (got 14 columns instead of 19)
#     Line #304 (got 15 columns instead of 19)
#     Line #305 (got 14 columns instead of 19)
#     Line #306 (got 14 columns instead of 19)
#     Line #307 (got 18 columns instead of 19)
#     Line #308 (got 14 columns instead of 19)
#     Line #309 (got 15 columns instead of 19)
#     Line #310 (got 18 columns instead of 19)
#     Line #311 (got 16 columns instead of 19)
#     Line #312 (got 14 columns instead of 19)
#     Line #313 (got 16 columns instead of 19)
#     Line #314 (got 14 columns instead of 19)
#     Line #315 (got 15 columns instead of 19)
#     Line #316 (got 17 columns instead of 19)
#     Line #317 (got 18 columns instead of 19)
#     Line #318 (got 16 columns instead of 19)
#     Line #319 (got 15 columns instead of 19)
#     Line #320 (got 17 columns instead of 19)
#     Line #321 (got 14 columns instead of 19)
#     Line #322 (got 13 columns instead of 19)
#     Line #323 (got 14 columns instead of 19)
#     Line #324 (got 16 columns instead of 19)
#     Line #325 (got 17 columns instead of 19)
#     Line #326 (got 15 columns instead of 19)
#     Line #327 (got 14 columns instead of 19)
#     Line #328 (got 18 columns instead of 19)
#     Line #329 (got 13 columns instead of 19)
#     Line #330 (got 13 columns instead of 19)
#     Line #331 (got 13 columns instead of 19)
#     Line #332 (got 18 columns instead of 19)
#     Line #333 (got 17 columns instead of 19)
#     Line #334 (got 15 columns instead of 19)
#     Line #335 (got 17 columns instead of 19)
#     Line #337 (got 16 columns instead of 19)
#     Line #338 (got 16 columns instead of 19)
#     Line #339 (got 14 columns instead of 19)
#     Line #340 (got 14 columns instead of 19)
#     Line #341 (got 15 columns instead of 19)
#     Line #342 (got 17 columns instead of 19)
#     Line #343 (got 16 columns instead of 19)
#     Line #345 (got 13 columns instead of 19)
#     Line #346 (got 14 columns instead of 19)
#     Line #347 (got 16 columns instead of 19)
#     Line #348 (got 13 columns instead of 19)
#     Line #349 (got 18 columns instead of 19)
#     Line #350 (got 15 columns instead of 19)
#     Line #351 (got 16 columns instead of 19)
#     Line #352 (got 15 columns instead of 19)
#     Line #353 (got 16 columns instead of 19)
#     Line #354 (got 15 columns instead of 19)
#     Line #355 (got 16 columns instead of 19)
#     Line #356 (got 15 columns instead of 19)
#     Line #357 (got 16 columns instead of 19)
#     Line #358 (got 18 columns instead of 19)
#     Line #359 (got 18 columns instead of 19)
#     Line #360 (got 16 columns instead of 19)
#     Line #361 (got 21 columns instead of 19)
#     Line #362 (got 17 columns instead of 19)
#     Line #363 (got 15 columns instead of 19)
#     Line #364 (got 14 columns instead of 19)
#     Line #365 (got 13 columns instead of 19)
#     Line #366 (got 17 columns instead of 19)
#     Line #367 (got 17 columns instead of 19)
#     Line #368 (got 13 columns instead of 19)
#     Line #369 (got 13 columns instead of 19)
#     Line #370 (got 14 columns instead of 19)
#     Line #371 (got 17 columns instead of 19)
#     Line #372 (got 13 columns instead of 19)
#     Line #373 (got 18 columns instead of 19)
#     Line #374 (got 18 columns instead of 19)
#     Line #375 (got 18 columns instead of 19)
#     Line #376 (got 17 columns instead of 19)
#     Line #377 (got 14 columns instead of 19)
#     Line #378 (got 16 columns instead of 19)
#     Line #379 (got 15 columns instead of 19)
#     Line #380 (got 21 columns instead of 19)
#     Line #381 (got 18 columns instead of 19)
#     Line #382 (got 17 columns instead of 19)
#     Line #383 (got 14 columns instead of 19)
#     Line #384 (got 13 columns instead of 19)
#     Line #385 (got 17 columns instead of 19)
#     Line #386 (got 16 columns instead of 19)
#     Line #387 (got 16 columns instead of 19)
#     Line #388 (got 16 columns instead of 19)
#     Line #390 (got 16 columns instead of 19)
#     Line #391 (got 15 columns instead of 19)
#     Line #392 (got 13 columns instead of 19)
#     Line #393 (got 15 columns instead of 19)
#     Line #394 (got 16 columns instead of 19)
#     Line #395 (got 18 columns instead of 19)
#     Line #396 (got 14 columns instead of 19)
#     Line #397 (got 14 columns instead of 19)
#     Line #398 (got 14 columns instead of 19)
#     Line #399 (got 13 columns instead of 19)
#     Line #400 (got 18 columns instead of 19)
#     Line #401 (got 20 columns instead of 19)
#     Line #403 (got 14 columns instead of 19)
#     Line #404 (got 14 columns instead of 19)
#     Line #405 (got 17 columns instead of 19)
#     Line #406 (got 13 columns instead of 19)
#     Line #407 (got 16 columns instead of 19)
#     Line #408 (got 17 columns instead of 19)
#     Line #409 (got 16 columns instead of 19)
#     Line #410 (got 13 columns instead of 19)
#     Line #411 (got 13 columns instead of 19)
#     Line #412 (got 16 columns instead of 19)
#     Line #413 (got 14 columns instead of 19)
#     Line #414 (got 15 columns instead of 19)
#     Line #415 (got 15 columns instead of 19)
#     Line #416 (got 15 columns instead of 19)
#     Line #417 (got 16 columns instead of 19)
#     Line #418 (got 16 columns instead of 19)
#     Line #419 (got 15 columns instead of 19)
#     Line #420 (got 15 columns instead of 19)
#     Line #421 (got 13 columns instead of 19)
#     Line #422 (got 15 columns instead of 19)
#     Line #423 (got 16 columns instead of 19)
#     Line #424 (got 14 columns instead of 19)
#     Line #425 (got 15 columns instead of 19)
#     Line #426 (got 16 columns instead of 19)
#     Line #427 (got 14 columns instead of 19)
#     Line #428 (got 15 columns instead of 19)
#     Line #429 (got 13 columns instead of 19)
#     Line #430 (got 18 columns instead of 19)
#     Line #431 (got 16 columns instead of 19)
#     Line #432 (got 16 columns instead of 19)
#     Line #433 (got 14 columns instead of 19)
#     Line #434 (got 15 columns instead of 19)
#     Line #435 (got 16 columns instead of 19)
#     Line #436 (got 14 columns instead of 19)
#     Line #437 (got 14 columns instead of 19)
#     Line #438 (got 15 columns instead of 19)
#     Line #439 (got 13 columns instead of 19)
#     Line #440 (got 18 columns instead of 19)
#     Line #441 (got 16 columns instead of 19)
#     Line #442 (got 18 columns instead of 19)
#     Line #443 (got 16 columns instead of 19)
#     Line #444 (got 15 columns instead of 19)
#     Line #445 (got 16 columns instead of 19)
#     Line #446 (got 13 columns instead of 19)
#     Line #447 (got 15 columns instead of 19)
#     Line #448 (got 14 columns instead of 19)
#     Line #449 (got 15 columns instead of 19)
#     Line #450 (got 16 columns instead of 19)
#     Line #451 (got 14 columns instead of 19)
#     Line #452 (got 17 columns instead of 19)
#     Line #453 (got 14 columns instead of 19)
#     Line #454 (got 14 columns instead of 19)
#     Line #456 (got 14 columns instead of 19)
#     Line #457 (got 14 columns instead of 19)
#     Line #458 (got 15 columns instead of 19)
#     Line #459 (got 14 columns instead of 19)
#     Line #460 (got 15 columns instead of 19)
#     Line #461 (got 16 columns instead of 19)
#     Line #462 (got 17 columns instead of 19)
#     Line #463 (got 15 columns instead of 19)
#     Line #464 (got 17 columns instead of 19)
#     Line #465 (got 20 columns instead of 19)
#     Line #466 (got 15 columns instead of 19)
#     Line #467 (got 16 columns instead of 19)
#     Line #468 (got 17 columns instead of 19)
#     Line #469 (got 15 columns instead of 19)
#     Line #470 (got 16 columns instead of 19)
#     Line #471 (got 15 columns instead of 19)
#     Line #472 (got 17 columns instead of 19)
#     Line #473 (got 15 columns instead of 19)
#     Line #474 (got 15 columns instead of 19)
#     Line #475 (got 12 columns instead of 19)
#     Line #476 (got 13 columns instead of 19)
#     Line #477 (got 14 columns instead of 19)
#     Line #478 (got 13 columns instead of 19)
#     Line #479 (got 18 columns instead of 19)
#     Line #480 (got 16 columns instead of 19)
#     Line #482 (got 17 columns instead of 19)
#     Line #483 (got 14 columns instead of 19)
#     Line #484 (got 16 columns instead of 19)
#     Line #485 (got 15 columns instead of 19)
#     Line #486 (got 21 columns instead of 19)
#     Line #487 (got 15 columns instead of 19)
#     Line #488 (got 15 columns instead of 19)
#     Line #489 (got 15 columns instead of 19)
#     Line #490 (got 13 columns instead of 19)
#     Line #491 (got 17 columns instead of 19)
#     Line #492 (got 13 columns instead of 19)
#     Line #493 (got 14 columns instead of 19)
#     Line #494 (got 16 columns instead of 19)
#     Line #495 (got 16 columns instead of 19)
#     Line #496 (got 15 columns instead of 19)
#     Line #497 (got 14 columns instead of 19)
#     Line #498 (got 16 columns instead of 19)
#     Line #499 (got 18 columns instead of 19)
#     Line #500 (got 22 columns instead of 19)
#     Line #501 (got 16 columns instead of 19)
#     Line #502 (got 14 columns instead of 19)
#     Line #503 (got 14 columns instead of 19)
#     Line #504 (got 12 columns instead of 19)
#     Line #505 (got 13 columns instead of 19)
#     Line #506 (got 13 columns instead of 19)
#     Line #507 (got 17 columns instead of 19)
#     Line #508 (got 21 columns instead of 19)
#     Line #509 (got 13 columns instead of 19)
#     Line #510 (got 15 columns instead of 19)
#     Line #511 (got 16 columns instead of 19)
#     Line #512 (got 14 columns instead of 19)
#     Line #513 (got 15 columns instead of 19)
#     Line #514 (got 15 columns instead of 19)
#     Line #515 (got 13 columns instead of 19)
#     Line #517 (got 14 columns instead of 19)
#     Line #518 (got 14 columns instead of 19)
#     Line #519 (got 14 columns instead of 19)
#     Line #520 (got 11 columns instead of 19)
#     Line #521 (got 14 columns instead of 19)
#     Line #522 (got 18 columns instead of 19)
#     Line #523 (got 15 columns instead of 19)
#     Line #524 (got 16 columns instead of 19)
#     Line #525 (got 15 columns instead of 19)
#     Line #526 (got 15 columns instead of 19)
#     Line #527 (got 18 columns instead of 19)
#     Line #528 (got 16 columns instead of 19)
#     Line #529 (got 13 columns instead of 19)
#     Line #530 (got 16 columns instead of 19)
#     Line #531 (got 16 columns instead of 19)
#     Line #532 (got 12 columns instead of 19)
#     Line #533 (got 14 columns instead of 19)
#     Line #534 (got 14 columns instead of 19)
#     Line #535 (got 15 columns instead of 19)
#     Line #536 (got 15 columns instead of 19)
#     Line #537 (got 14 columns instead of 19)
#     Line #538 (got 16 columns instead of 19)
#     Line #539 (got 14 columns instead of 19)
#     Line #540 (got 14 columns instead of 19)
#     Line #541 (got 15 columns instead of 19)
#     Line #543 (got 16 columns instead of 19)
#     Line #545 (got 18 columns instead of 19)
#     Line #546 (got 15 columns instead of 19)
#     Line #547 (got 16 columns instead of 19)
#     Line #548 (got 14 columns instead of 19)
#     Line #549 (got 15 columns instead of 19)
#     Line #550 (got 16 columns instead of 19)
#     Line #551 (got 14 columns instead of 19)
#     Line #552 (got 15 columns instead of 19)
#     Line #553 (got 17 columns instead of 19)
#     Line #554 (got 16 columns instead of 19)
#     Line #555 (got 13 columns instead of 19)
#     Line #556 (got 14 columns instead of 19)
#     Line #557 (got 15 columns instead of 19)
#     Line #558 (got 15 columns instead of 19)
#     Line #559 (got 15 columns instead of 19)
#     Line #560 (got 14 columns instead of 19)
#     Line #561 (got 13 columns instead of 19)
#     Line #562 (got 14 columns instead of 19)
#     Line #563 (got 15 columns instead of 19)
#     Line #564 (got 13 columns instead of 19)
#     Line #565 (got 14 columns instead of 19)
#     Line #566 (got 16 columns instead of 19)
#     Line #567 (got 17 columns instead of 19)
#     Line #568 (got 15 columns instead of 19)
#     Line #569 (got 16 columns instead of 19)
#     Line #570 (got 18 columns instead of 19)
#     Line #571 (got 15 columns instead of 19)
#     Line #572 (got 14 columns instead of 19)
#     Line #573 (got 16 columns instead of 19)
#     Line #574 (got 17 columns instead of 19)
#     Line #575 (got 14 columns instead of 19)
#     Line #576 (got 15 columns instead of 19)
#     Line #577 (got 14 columns instead of 19)
#     Line #578 (got 17 columns instead of 19)
#     Line #579 (got 18 columns instead of 19)
#     Line #581 (got 18 columns instead of 19)
#     Line #582 (got 14 columns instead of 19)
#     Line #583 (got 13 columns instead of 19)
#     Line #584 (got 14 columns instead of 19)
#     Line #585 (got 18 columns instead of 19)
#     Line #586 (got 15 columns instead of 19)
#     Line #587 (got 18 columns instead of 19)
#     Line #588 (got 16 columns instead of 19)
#     Line #589 (got 15 columns instead of 19)
#     Line #590 (got 13 columns instead of 19)
#     Line #591 (got 15 columns instead of 19)
#     Line #592 (got 14 columns instead of 19)
#     Line #593 (got 15 columns instead of 19)
#     Line #594 (got 16 columns instead of 19)
#     Line #595 (got 14 columns instead of 19)
#     Line #596 (got 15 columns instead of 19)
#     Line #597 (got 18 columns instead of 19)
#     Line #598 (got 17 columns instead of 19)
#     Line #599 (got 15 columns instead of 19)
#     Line #600 (got 16 columns instead of 19)
#     Line #601 (got 18 columns instead of 19)
#     Line #602 (got 13 columns instead of 19)
#     Line #604 (got 13 columns instead of 19)
#     Line #605 (got 15 columns instead of 19)
#     Line #606 (got 14 columns instead of 19)
#     Line #607 (got 16 columns instead of 19)
#     Line #608 (got 15 columns instead of 19)
#     Line #609 (got 20 columns instead of 19)
#     Line #610 (got 13 columns instead of 19)
#     Line #611 (got 15 columns instead of 19)
#     Line #612 (got 14 columns instead of 19)
#     Line #613 (got 17 columns instead of 19)
#     Line #614 (got 15 columns instead of 19)
#     Line #615 (got 17 columns instead of 19)
#     Line #616 (got 13 columns instead of 19)
#     Line #617 (got 15 columns instead of 19)
#     Line #618 (got 15 columns instead of 19)
#     Line #619 (got 14 columns instead of 19)
#     Line #620 (got 13 columns instead of 19)
#     Line #621 (got 16 columns instead of 19)
#     Line #622 (got 16 columns instead of 19)
#     Line #623 (got 14 columns instead of 19)
#     Line #624 (got 16 columns instead of 19)
#     Line #625 (got 13 columns instead of 19)
#     Line #626 (got 15 columns instead of 19)
#     Line #627 (got 15 columns instead of 19)
#     Line #628 (got 15 columns instead of 19)
#     Line #629 (got 20 columns instead of 19)
#     Line #630 (got 16 columns instead of 19)
#     Line #631 (got 14 columns instead of 19)
#     Line #632 (got 17 columns instead of 19)
#     Line #633 (got 14 columns instead of 19)
#     Line #634 (got 17 columns instead of 19)
#     Line #635 (got 17 columns instead of 19)
#     Line #637 (got 13 columns instead of 19)
#     Line #638 (got 14 columns instead of 19)
#     Line #639 (got 17 columns instead of 19)
#     Line #640 (got 13 columns instead of 19)
#     Line #641 (got 13 columns instead of 19)
#     Line #642 (got 17 columns instead of 19)
#     Line #643 (got 15 columns instead of 19)
#     Line #644 (got 14 columns instead of 19)
#     Line #645 (got 14 columns instead of 19)
#     Line #646 (got 14 columns instead of 19)
#     Line #647 (got 15 columns instead of 19)
#     Line #648 (got 14 columns instead of 19)
#     Line #649 (got 18 columns instead of 19)
#     Line #650 (got 12 columns instead of 19)
#     Line #651 (got 16 columns instead of 19)
#     Line #652 (got 17 columns instead of 19)
#     Line #653 (got 16 columns instead of 19)
#     Line #654 (got 15 columns instead of 19)
#     Line #655 (got 15 columns instead of 19)
#     Line #656 (got 15 columns instead of 19)
#     Line #657 (got 13 columns instead of 19)
#     Line #658 (got 16 columns instead of 19)
#     Line #659 (got 21 columns instead of 19)
#     Line #660 (got 17 columns instead of 19)
#     Line #661 (got 15 columns instead of 19)
#     Line #662 (got 13 columns instead of 19)
#     Line #663 (got 14 columns instead of 19)
#     Line #664 (got 18 columns instead of 19)
#     Line #665 (got 14 columns instead of 19)
#     Line #666 (got 17 columns instead of 19)
#     Line #668 (got 14 columns instead of 19)
#     Line #669 (got 15 columns instead of 19)
#     Line #670 (got 14 columns instead of 19)
#     Line #671 (got 15 columns instead of 19)
#     Line #672 (got 14 columns instead of 19)
#     Line #673 (got 15 columns instead of 19)
#     Line #674 (got 16 columns instead of 19)
#     Line #675 (got 13 columns instead of 19)
#     Line #676 (got 12 columns instead of 19)
#     Line #677 (got 13 columns instead of 19)
#     Line #678 (got 16 columns instead of 19)
#     Line #679 (got 18 columns instead of 19)
#     Line #680 (got 14 columns instead of 19)
#     Line #681 (got 16 columns instead of 19)
#     Line #682 (got 16 columns instead of 19)
#     Line #683 (got 17 columns instead of 19)
#     Line #684 (got 15 columns instead of 19)
#     Line #685 (got 14 columns instead of 19)
#     Line #686 (got 15 columns instead of 19)
#     Line #687 (got 18 columns instead of 19)
#     Line #688 (got 14 columns instead of 19)
#     Line #689 (got 18 columns instead of 19)
#     Line #690 (got 14 columns instead of 19)
#     Line #691 (got 14 columns instead of 19)
#     Line #692 (got 14 columns instead of 19)
#     Line #693 (got 16 columns instead of 19)
#     Line #694 (got 17 columns instead of 19)
#     Line #695 (got 15 columns instead of 19)
#     Line #696 (got 14 columns instead of 19)
#     Line #697 (got 14 columns instead of 19)
#     Line #698 (got 14 columns instead of 19)
#     Line #699 (got 15 columns instead of 19)
#     Line #700 (got 14 columns instead of 19)
#     Line #701 (got 16 columns instead of 19)
#     Line #702 (got 15 columns instead of 19)
#     Line #703 (got 15 columns instead of 19)
#     Line #704 (got 18 columns instead of 19)
#     Line #705 (got 15 columns instead of 19)
#     Line #706 (got 15 columns instead of 19)
#     Line #707 (got 16 columns instead of 19)
#     Line #708 (got 16 columns instead of 19)
#     Line #709 (got 13 columns instead of 19)
#     Line #710 (got 13 columns instead of 19)
#     Line #711 (got 13 columns instead of 19)
#     Line #712 (got 16 columns instead of 19)
#     Line #713 (got 17 columns instead of 19)
#     Line #714 (got 13 columns instead of 19)
#     Line #715 (got 17 columns instead of 19)
#     Line #716 (got 12 columns instead of 19)
#     Line #717 (got 14 columns instead of 19)
#     Line #718 (got 15 columns instead of 19)
#     Line #719 (got 13 columns instead of 19)
#     Line #721 (got 16 columns instead of 19)
#     Line #722 (got 16 columns instead of 19)
#     Line #723 (got 18 columns instead of 19)
#     Line #724 (got 17 columns instead of 19)
#     Line #725 (got 15 columns instead of 19)
#     Line #726 (got 17 columns instead of 19)
#     Line #727 (got 17 columns instead of 19)
#     Line #728 (got 12 columns instead of 19)
#     Line #729 (got 15 columns instead of 19)
#     Line #730 (got 15 columns instead of 19)
#     Line #731 (got 20 columns instead of 19)
#     Line #732 (got 18 columns instead of 19)
#     Line #733 (got 13 columns instead of 19)
#     Line #734 (got 17 columns instead of 19)
#     Line #735 (got 16 columns instead of 19)
#     Line #736 (got 18 columns instead of 19)
#     Line #737 (got 13 columns instead of 19)
#     Line #738 (got 15 columns instead of 19)
#     Line #739 (got 17 columns instead of 19)
#     Line #740 (got 17 columns instead of 19)
#     Line #741 (got 15 columns instead of 19)
#     Line #742 (got 15 columns instead of 19)
#     Line #743 (got 14 columns instead of 19)
#     Line #744 (got 14 columns instead of 19)
#     Line #745 (got 16 columns instead of 19)
#     Line #746 (got 16 columns instead of 19)
#     Line #747 (got 14 columns instead of 19)
#     Line #748 (got 16 columns instead of 19)
#     Line #749 (got 16 columns instead of 19)
#     Line #750 (got 18 columns instead of 19)
#     Line #751 (got 20 columns instead of 19)
#     Line #752 (got 13 columns instead of 19)
#     Line #753 (got 15 columns instead of 19)
#     Line #754 (got 15 columns instead of 19)
#     Line #755 (got 15 columns instead of 19)
#     Line #756 (got 16 columns instead of 19)
#     Line #758 (got 18 columns instead of 19)
#     Line #759 (got 13 columns instead of 19)
#     Line #760 (got 14 columns instead of 19)
#     Line #762 (got 16 columns instead of 19)
#     Line #763 (got 13 columns instead of 19)
#     Line #764 (got 16 columns instead of 19)
#     Line #765 (got 14 columns instead of 19)
#     Line #766 (got 16 columns instead of 19)
#     Line #767 (got 13 columns instead of 19)
#     Line #768 (got 16 columns instead of 19)
#     Line #769 (got 14 columns instead of 19)
#     Line #770 (got 18 columns instead of 19)
#     Line #771 (got 14 columns instead of 19)
#     Line #772 (got 17 columns instead of 19)
#     Line #773 (got 14 columns instead of 19)
#     Line #774 (got 15 columns instead of 19)
#     Line #775 (got 15 columns instead of 19)
#     Line #776 (got 14 columns instead of 19)
#     Line #777 (got 16 columns instead of 19)
#     Line #778 (got 16 columns instead of 19)
#     Line #779 (got 15 columns instead of 19)
#     Line #780 (got 14 columns instead of 19)
#     Line #781 (got 17 columns instead of 19)
#     Line #782 (got 14 columns instead of 19)
#     Line #783 (got 15 columns instead of 19)
#     Line #784 (got 13 columns instead of 19)
#     Line #785 (got 13 columns instead of 19)
#     Line #786 (got 15 columns instead of 19)
#     Line #787 (got 15 columns instead of 19)
#     Line #788 (got 15 columns instead of 19)
#     Line #789 (got 15 columns instead of 19)
#     Line #790 (got 15 columns instead of 19)
#     Line #791 (got 14 columns instead of 19)
#     Line #792 (got 15 columns instead of 19)
#     Line #793 (got 15 columns instead of 19)
#     Line #794 (got 15 columns instead of 19)
#     Line #795 (got 14 columns instead of 19)
#     Line #796 (got 16 columns instead of 19)
#     Line #797 (got 13 columns instead of 19)
#     Line #798 (got 13 columns instead of 19)
#     Line #799 (got 13 columns instead of 19)
#     Line #800 (got 20 columns instead of 19)
#     Line #801 (got 14 columns instead of 19)
#     Line #802 (got 15 columns instead of 19)
#     Line #804 (got 14 columns instead of 19)
#     Line #805 (got 16 columns instead of 19)
#     Line #806 (got 16 columns instead of 19)
#     Line #807 (got 14 columns instead of 19)
#     Line #808 (got 15 columns instead of 19)
#     Line #809 (got 18 columns instead of 19)
#     Line #810 (got 16 columns instead of 19)
#     Line #811 (got 18 columns instead of 19)
#     Line #812 (got 16 columns instead of 19)
#     Line #813 (got 15 columns instead of 19)
#     Line #814 (got 15 columns instead of 19)
#     Line #815 (got 15 columns instead of 19)
#     Line #816 (got 14 columns instead of 19)
#     Line #817 (got 13 columns instead of 19)
#     Line #818 (got 14 columns instead of 19)
#     Line #819 (got 13 columns instead of 19)
#     Line #820 (got 15 columns instead of 19)
#     Line #821 (got 17 columns instead of 19)
#     Line #822 (got 17 columns instead of 19)
#     Line #823 (got 16 columns instead of 19)
#     Line #824 (got 14 columns instead of 19)
#     Line #825 (got 13 columns instead of 19)
#     Line #826 (got 14 columns instead of 19)
#     Line #827 (got 15 columns instead of 19)
#     Line #828 (got 16 columns instead of 19)
#     Line #829 (got 14 columns instead of 19)
#     Line #830 (got 17 columns instead of 19)
#     Line #831 (got 12 columns instead of 19)
#     Line #832 (got 13 columns instead of 19)
#     Line #833 (got 13 columns instead of 19)
#     Line #834 (got 11 columns instead of 19)
#     Line #835 (got 15 columns instead of 19)
#     Line #836 (got 14 columns instead of 19)
#     Line #837 (got 14 columns instead of 19)
#     Line #839 (got 15 columns instead of 19)
#     Line #840 (got 17 columns instead of 19)
#     Line #841 (got 17 columns instead of 19)
#     Line #842 (got 17 columns instead of 19)
#     Line #843 (got 16 columns instead of 19)
#     Line #844 (got 15 columns instead of 19)
#     Line #846 (got 15 columns instead of 19)
#     Line #847 (got 16 columns instead of 19)
#     Line #848 (got 17 columns instead of 19)
#     Line #849 (got 12 columns instead of 19)
#     Line #850 (got 13 columns instead of 19)
#     Line #851 (got 15 columns instead of 19)
#     Line #852 (got 20 columns instead of 19)
#     Line #853 (got 15 columns instead of 19)
#     Line #854 (got 16 columns instead of 19)
#     Line #855 (got 12 columns instead of 19)
#     Line #856 (got 15 columns instead of 19)
#     Line #857 (got 15 columns instead of 19)
#     Line #858 (got 16 columns instead of 19)
#     Line #859 (got 20 columns instead of 19)
#     Line #860 (got 18 columns instead of 19)
#     Line #861 (got 14 columns instead of 19)
#     Line #862 (got 17 columns instead of 19)
#     Line #863 (got 17 columns instead of 19)
#     Line #864 (got 17 columns instead of 19)
#     Line #865 (got 14 columns instead of 19)
#     Line #866 (got 15 columns instead of 19)
#     Line #867 (got 14 columns instead of 19)
#     Line #868 (got 18 columns instead of 19)
#     Line #869 (got 13 columns instead of 19)
#     Line #870 (got 17 columns instead of 19)
#     Line #871 (got 18 columns instead of 19)
#     Line #872 (got 15 columns instead of 19)
#     Line #873 (got 12 columns instead of 19)
#     Line #874 (got 13 columns instead of 19)
#     Line #875 (got 16 columns instead of 19)
#     Line #876 (got 16 columns instead of 19)
#     Line #877 (got 13 columns instead of 19)
#     Line #878 (got 14 columns instead of 19)
#     Line #879 (got 15 columns instead of 19)
#     Line #880 (got 17 columns instead of 19)
#     Line #881 (got 15 columns instead of 19)
#     Line #882 (got 16 columns instead of 19)
#     Line #883 (got 13 columns instead of 19)
#     Line #884 (got 16 columns instead of 19)
#     Line #885 (got 14 columns instead of 19)
#     Line #887 (got 16 columns instead of 19)
#     Line #888 (got 18 columns instead of 19)
#     Line #889 (got 15 columns instead of 19)
#     Line #890 (got 15 columns instead of 19)
#     Line #891 (got 12 columns instead of 19)
#     Line #892 (got 15 columns instead of 19)
#     Line #893 (got 12 columns instead of 19)
#     Line #894 (got 15 columns instead of 19)
#     Line #895 (got 15 columns instead of 19)
#     Line #896 (got 16 columns instead of 19)
#     Line #897 (got 18 columns instead of 19)
#     Line #898 (got 13 columns instead of 19)
#     Line #899 (got 15 columns instead of 19)
#     Line #900 (got 16 columns instead of 19)
#     Line #901 (got 12 columns instead of 19)
#     Line #902 (got 14 columns instead of 19)
#     Line #903 (got 16 columns instead of 19)
#     Line #904 (got 14 columns instead of 19)
#     Line #905 (got 13 columns instead of 19)
#     Line #906 (got 15 columns instead of 19)
#     Line #907 (got 17 columns instead of 19)
#     Line #908 (got 14 columns instead of 19)
#     Line #910 (got 15 columns instead of 19)
#     Line #911 (got 16 columns instead of 19)
#     Line #912 (got 15 columns instead of 19)
#     Line #913 (got 14 columns instead of 19)
#     Line #914 (got 15 columns instead of 19)
#     Line #915 (got 15 columns instead of 19)
#     Line #916 (got 17 columns instead of 19)
#     Line #917 (got 16 columns instead of 19)
#     Line #918 (got 14 columns instead of 19)
#     Line #919 (got 16 columns instead of 19)
