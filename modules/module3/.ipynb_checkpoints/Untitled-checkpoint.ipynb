# %%
# %matplotlib inline
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
student_attendance = {'day1':33, 'day2':34,'day3':29,'day4':31,'day5':28,'day6':26,'day7':30}
ply.figure()
plt.plot(student_attendance.keys(), student_attendance.values())
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-94ff328ec5cc> in <module>
#       1 student_attendance = {'day1':33, 'day2':34,'day3':29,'day4':31,'day5':28,'day6':26,'day7':30}
#       2
# ----> 3 plt.plot(student_attendance.keys(), student_attendance.values())
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
