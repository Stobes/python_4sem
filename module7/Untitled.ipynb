# %%
from random import randrange
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def create_babies(amount):
    lst = []
    for x in range(amount):
        height = randrange(45, 60)
        weight = randrange(3300, 4200)
        age_in_month = randrange(2, 24)
        lst.append([height, weight, age_in_month])
    return np.asarray(lst)

data_3d = create_babies(1000)
x, y, z = data_3d[:,0], data_3d[:,1], data_3d[:,2]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, linewidth=0.2)

plt.show()

# %%
shoppers = {
'Paula':{'Is':4,'Juice':2,'Kakao':3,'Lagkager':2},
'Peter':{'Is':2,'Juice':5,'Kakao':0, 'Lagkager':4},
'Pandora':{'Is':5,'Juice':3, 'Kakao':4, 'Lagkager':5},
'Pietro':{'Is':1,'Juice':8, 'Kakao':9, 'Lagkager':1}
}
shop_prices = {
    'Netto': {'Is':10.50,'Juice':2.25,'Kakao':4.50,'Lagkager':33.50},
    'Fakta': {'Is':4.00,'Juice':4.50,'Kakao':6.25,'Lagkager':20.00}
}

df1 = pd.DataFrame(shoppers).T
df2 = pd.DataFrame(shop_prices).T

print(df1)
print(df2)

df1.to_numpy()
df2.to_numpy()

res_df = df2.to_numpy().dot(df1.to_numpy())

print(pd.DataFrame(res_df))
# Out:
#          Is  Juice  Kakao  Lagkager
# Paula     4      2      3         2
# Peter     2      5      0         4
# Pandora   5      3      4         5
# Pietro    1      8      9         1
#          Is  Juice  Kakao  Lagkager
# Netto  10.5   2.25   4.50      33.5
# Fakta   4.0   4.50   6.25      20.0
#         0       1      2      3
# 0  102.50  313.75  351.0  86.00
# 1   76.25  209.25  217.0  77.25
